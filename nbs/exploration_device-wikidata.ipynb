# %%
import requests
import os
import pandas as pd

# %% [markdown]
#  - Filter for electronic devices
#
#  - P31 is the property for "instance of"
#
#  - P279 is the property for "subclass of"
#
#  - Q71266741 is the item for "smartphone"
#
#  - mobiled phone has the following ID: Q17517
#
#  - Q16338 for personal computer
#  - ?device wdt:P31/wdt:P279*  ?subclass.
#
#  - ?subclass wdt:P279 ?metaclass .
#
#  - ?metaclass wdt:P642 wd:Q68 .

# %%
# Define the properties we want to retrieve
# properties = ['inception date', 'mass', 'part of the series', 'subclass of', 'instance of', 'color', 'manufacturer', 'CPU', 'memory capacity', 'max size', 'energy storage capacity', 'operating system', 'height', 'width', 'thickness', 'display technology', 'price']

# Construct the query string
query = """
SELECT ?device ?deviceLabel ?colorLabel  ?inception ?precisionLabel ?instance_ofLabel ?height ?unitHeightLabel ?width ?unitWidthLabel ?weight ?unitWeightLabel ?price ?unitPriceLabel
WHERE
{
  # ?device wdt:P31/wdt:P279* [p:P279*/pq:P642*[wdt:P279* wd:Q68]].

  OPTIONAL {?device wdt:P31 ?instance_of.}
  OPTIONAL {?device wdt:P462 ?color.}
  OPTIONAL {?device p:P2284/psv:P2284 [ wikibase:quantityAmount     ?price ;
                                        wikibase:quantityUnit       ?unitPrice].}
                                        
  OPTIONAL {?device p:P2048/psv:P2048 [ wikibase:quantityAmount     ?height ;
                                        wikibase:quantityUnit       ?unitHeight].}
  OPTIONAL {?device p:P2049/psv:P2049 [ wikibase:quantityAmount     ?width ;
                                        wikibase:quantityUnit       ?unitWidth ].}
  OPTIONAL {?device p:P2067/psv:P2067 [ wikibase:quantityAmount     ?weight ;
                                        wikibase:quantityUnit       ?unitWeight].}  
  OPTIONAL {?device p:P571/psv:P571 ?timenode .
            # ?timenode wikibase:timeValue         ?inception.
            # ?timenode wikibase:timePrecision     ?timeprecision.
            # get the label of time precision
            {SELECT ?precision (xsd:integer(?precisionDecimal) AS ?timeprecision) {
              # ?precision  wdt:P2803  ?precisionDecimal .}
            }
          }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""

# Define the endpoint URL for the Wikidata SPARQL API
url = "https://query.wikidata.org/sparql"

# Define the headers for the request
headers = {"Accept": "application/sparql-results+json"}

# Send the request and get the response
response = requests.get(url, headers=headers, params={"query": query, "timeout": "600000000"})

# Parse the response into a pandas dataframe
data = pd.read_json(response.content.decode())["results"]["bindings"]
df_full = pd.json_normalize(data)
df_full.fillna(value="<na>", inplace=True)
df_full
# Out:
#        device.type                               device.value
# 0              uri   http://www.wikidata.org/entity/Q42266831  \
# 1              uri   http://www.wikidata.org/entity/Q42266831
# 2              uri   http://www.wikidata.org/entity/Q42266831
# 3              uri   http://www.wikidata.org/entity/Q42266831
# 4              uri   http://www.wikidata.org/entity/Q42266831
# ...            ...                                        ...
# 128543         uri  http://www.wikidata.org/entity/Q117089235
# 128544         uri  http://www.wikidata.org/entity/Q117089271
# 128545         uri  http://www.wikidata.org/entity/Q117089310
# 128546         uri  http://www.wikidata.org/entity/Q117105107
# 128547         uri  http://www.wikidata.org/entity/Q117154490
#
#                                inception.datatype inception.type
# 0       http://www.w3.org/2001/XMLSchema#dateTime        literal  \
# 1       http://www.w3.org/2001/XMLSchema#dateTime        literal
# 2       http://www.w3.org/2001/XMLSchema#dateTime        literal
# 3       http://www.w3.org/2001/XMLSchema#dateTime        literal
# 4       http://www.w3.org/2001/XMLSchema#dateTime        literal
# ...                                           ...            ...
# 128543                                       <na>           <na>
# 128544                                       <na>           <na>
# 128545                                       <na>           <na>
# 128546                                       <na>           <na>
# 128547                                       <na>           <na>
#
#              inception.value deviceLabel.xml:lang deviceLabel.type
# 0       2017-01-01T00:00:00Z                   en          literal  \
# 1       2017-01-01T00:00:00Z                   en          literal
# 2       2017-01-01T00:00:00Z                   en          literal
# 3       2017-01-01T00:00:00Z                   en          literal
# 4       2017-01-01T00:00:00Z                   en          literal
# ...                      ...                  ...              ...
# 128543                  <na>                   en          literal
# 128544                  <na>                   en          literal
# 128545                  <na>                   en          literal
# 128546                  <na>                 <na>          literal
# 128547                  <na>                   en          literal
#
#             deviceLabel.value precisionLabel.xml:lang precisionLabel.type
# 0                     Nokia 7                      en             literal  \
# 1                     Nokia 7                      en             literal
# 2                     Nokia 7                      en             literal
# 3                     Nokia 7                      en             literal
# 4                     Nokia 7                      en             literal
# ...                       ...                     ...                 ...
# 128543              Chameleon                    <na>                <na>
# 128544   zope.contentprovider                    <na>                <na>
# 128545           z3c.ptcompat                    <na>                <na>
# 128546             Q117105107                    <na>                <na>
# 128547  Samsung Galaxy A54 5G                    <na>                <na>
#
#         ... unitWeightLabel.value price.datatype price.type price.value
# 0       ...                  <na>           <na>       <na>        <na>  \
# 1       ...                  <na>           <na>       <na>        <na>
# 2       ...                  <na>           <na>       <na>        <na>
# 3       ...                  <na>           <na>       <na>        <na>
# 4       ...                  <na>           <na>       <na>        <na>
# ...     ...                   ...            ...        ...         ...
# 128543  ...                  <na>           <na>       <na>        <na>
# 128544  ...                  <na>           <na>       <na>        <na>
# 128545  ...                  <na>           <na>       <na>        <na>
# 128546  ...                  <na>           <na>       <na>        <na>
# 128547  ...                  <na>           <na>       <na>        <na>
#
#        unitPriceLabel.xml:lang unitPriceLabel.type unitPriceLabel.value
# 0                         <na>                <na>                 <na>  \
# 1                         <na>                <na>                 <na>
# 2                         <na>                <na>                 <na>
# 3                         <na>                <na>                 <na>
# 4                         <na>                <na>                 <na>
# ...                        ...                 ...                  ...
# 128543                    <na>                <na>                 <na>
# 128544                    <na>                <na>                 <na>
# 128545                    <na>                <na>                 <na>
# 128546                    <na>                <na>                 <na>
# 128547                    <na>                <na>                 <na>
#
#        colorLabel.xml:lang colorLabel.type colorLabel.value
# 0                     <na>            <na>             <na>
# 1                     <na>            <na>             <na>
# 2                     <na>            <na>             <na>
# 3                     <na>            <na>             <na>
# 4                     <na>            <na>             <na>
# ...                    ...             ...              ...
# 128543                <na>            <na>             <na>
# 128544                <na>            <na>             <na>
# 128545                <na>            <na>             <na>
# 128546                <na>            <na>             <na>
# 128547                <na>            <na>             <na>
#
# [128548 rows x 41 columns]

# %%
all(["Q" in item["device"]["value"] for item in data])
# Out:
# True

# %%
[item["device"] for item in data if item["device"]["value"].endswith("Q49046")]
# Out:
# [{'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'},
#  {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q49046'}]

# %%
# group by deviceLabel and keep the whole set
df = df_full.groupby('deviceLabel.value').agg(lambda x: list(set(x))).reset_index()
# select only relevant columns
df = df[["device.value", 'deviceLabel.value', 'colorLabel.value', 'inception.value', 'precisionLabel.value', 'instance_ofLabel.value', 'height.value', 'unitHeightLabel.value', 'width.value', 'unitWidthLabel.value', 'weight.value', 'unitWeightLabel.value', 'price.value', 'unitPriceLabel.value']]
# rename columns: simplify and make consistent snake_case with main_unit naming scheme like height_unit
df.columns = ["ID", 'device', 'color', 'inception', 'precision', 'instance_ofLabel', 'height', 'height_unit', 'width', 'width_unit', 'weight', 'weight_unit', 'price', 'price_unit']
df
# Out:
#                                                 ID                   device
# 0       [http://www.wikidata.org/entity/Q30015097]          "BeeZy" BG-1000  \
# 1       [http://www.wikidata.org/entity/Q72908471]     "PARAM Yuva" Cluster
# 2       [http://www.wikidata.org/entity/Q74585009]                        1
# 3         [http://www.wikidata.org/entity/Q161255]             1&1 SmartPad
# 4       [http://www.wikidata.org/entity/Q97994612]           1.8-inch drive
# ...                                            ...                      ...
# 13105  [http://www.wikidata.org/entity/Q107386742]        zvmcloudconnector
# 13106  [http://www.wikidata.org/entity/Q107386259]                   zxcvbn
# 13107     [http://www.wikidata.org/entity/Q290639]                   Étoilé
# 13108   [http://www.wikidata.org/entity/Q73403816]  Świerk Computing Centre
# 13109    [http://www.wikidata.org/entity/Q1213569]                      М-1
#
#         color               inception precision       instance_ofLabel
# 0      [<na>]  [1978-01-01T00:00:00Z]    [year]             [computer]  \
# 1      [<na>]                  [<na>]    [<na>]        [supercomputer]
# 2      [<na>]                  [<na>]    [<na>]        [supercomputer]
# 3      [<na>]                  [<na>]    [<na>]      [tablet computer]
# 4      [<na>]                  [<na>]    [<na>]    [drive form factor]
# ...       ...                     ...       ...                    ...
# 13105  [<na>]                  [<na>]    [<na>]       [Python library]
# 13106  [<na>]                  [<na>]    [<na>]       [Python library]
# 13107  [<na>]                  [<na>]    [<na>]  [desktop environment]
# 13108  [<na>]                  [<na>]    [<na>]        [supercomputer]
# 13109  [<na>]                  [<na>]    [<na>]             [computer]
#
#         height   height_unit   width    width_unit  weight weight_unit
# 0       [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]  \
# 1       [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 2       [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 3      [196.6]  [millimetre]   [130]  [millimetre]   [470]      [gram]
# 4       [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# ...        ...           ...     ...           ...     ...         ...
# 13105   [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 13106   [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 13107   [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 13108   [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
# 13109   [<na>]        [<na>]  [<na>]        [<na>]  [<na>]      [<na>]
#
#         price price_unit
# 0      [<na>]     [<na>]
# 1      [<na>]     [<na>]
# 2      [<na>]     [<na>]
# 3      [<na>]     [<na>]
# 4      [<na>]     [<na>]
# ...       ...        ...
# 13105  [<na>]     [<na>]
# 13106  [<na>]     [<na>]
# 13107  [<na>]     [<na>]
# 13108  [<na>]     [<na>]
# 13109  [<na>]     [<na>]
#
# [13110 rows x 14 columns]

# %%
df[df["device"].apply(lambda x: x.lower()).str.contains("iphone")]
# Out:
#                                                ID                      device
# 9606     [http://www.wikidata.org/entity/Q621427]                      iPhone  \
# 9607  [http://www.wikidata.org/entity/Q100332903]                   iPhone 12
# 9608  [http://www.wikidata.org/entity/Q108118280]                   iPhone 13
# 9609  [http://www.wikidata.org/entity/Q108541719]               iPhone 13 Pro
# 9610  [http://www.wikidata.org/entity/Q108541741]           iPhone 13 Pro Max
# 9611  [http://www.wikidata.org/entity/Q108541666]              iPhone 13 mini
# 9612  [http://www.wikidata.org/entity/Q110397828]                   iPhone 14
# 9613  [http://www.wikidata.org/entity/Q113816207]              iPhone 14 Plus
# 9614  [http://www.wikidata.org/entity/Q113800722]               iPhone 14 Pro
# 9615  [http://www.wikidata.org/entity/Q113816991]           iPhone 14 Pro Max
# 9616     [http://www.wikidata.org/entity/Q300859]                  iPhone 3GS
# 9617   [http://www.wikidata.org/entity/Q66816688]      iPhone 5s, model A1533
# 9618   [http://www.wikidata.org/entity/Q20966885]              iPhone 6S Plus
# 9619   [http://www.wikidata.org/entity/Q26831164]                    iPhone 7
# 9620   [http://www.wikidata.org/entity/Q23309966]  iPhone SE (1st generation)
#
#                                                   color
# 9606                                            [black]  \
# 9607                                             [<na>]
# 9608            [white, Product Red, pink, blue, black]
# 9609                     [silver, graphite, gold, blue]
# 9610                     [silver, graphite, gold, blue]
# 9611                                             [<na>]
# 9612  [midnight blue, starlight, Product Red, blue, ...
# 9613                                             [<na>]
# 9614                             [silver, gold, violet]
# 9615                                             [<na>]
# 9616                                     [white, black]
# 9617                                             [<na>]
# 9618                                             [<na>]
# 9619              [rose gold, red, gold, silver, black]
# 9620                    [silver, gold, rose gold, grey]
#
#                    inception precision    instance_ofLabel   height
# 9606  [2007-01-09T00:00:00Z]     [day]  [smartphone model]    [4.5]  \
# 9607                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9608  [2021-09-14T00:00:00Z]     [day]  [smartphone model]  [146.7]
# 9609  [2021-09-14T00:00:00Z]     [day]  [smartphone model]  [146.7]
# 9610                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9611                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9612                  [<na>]    [<na>]  [smartphone model]  [146.7]
# 9613                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9614                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9615                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9616  [2009-06-08T00:00:00Z]     [day]  [smartphone model]  [115.5]
# 9617                  [<na>]    [<na>]  [smartphone model]   [<na>]
# 9618  [2015-09-09T00:00:00Z]     [day]  [smartphone model]  [158.2]
# 9619  [2016-09-07T00:00:00Z]     [day]        [smartphone]  [138.3]
# 9620                  [<na>]    [<na>]  [smartphone model]  [123.8]
#
#        height_unit   width    width_unit      weight    weight_unit
# 9606        [inch]   [2.4]        [inch]  [4.8, 135]  [ounce, gram]  \
# 9607        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9608  [millimetre]  [71.5]  [millimetre]       [173]         [gram]
# 9609  [millimetre]  [71.5]  [millimetre]       [204]         [gram]
# 9610        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9611        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9612  [millimetre]  [71.5]  [millimetre]       [172]         [gram]
# 9613        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9614        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9615        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9616  [millimetre]  [62.1]  [millimetre]       [135]         [gram]
# 9617        [<na>]  [<na>]        [<na>]      [<na>]         [<na>]
# 9618  [millimetre]  [77.9]  [millimetre]       [192]         [gram]
# 9619  [millimetre]  [67.1]  [millimetre]       [138]         [gram]
# 9620  [millimetre]  [58.6]  [millimetre]       [113]         [gram]
#
#                               price              price_unit
# 9606                         [<na>]                  [<na>]
# 9607                         [<na>]                  [<na>]
# 9608              [1029, 909, 1259]                  [euro]
# 9609                         [<na>]                  [<na>]
# 9610                         [<na>]                  [<na>]
# 9611                         [<na>]                  [<na>]
# 9612                          [799]  [United States dollar]
# 9613                          [899]  [United States dollar]
# 9614                         [<na>]                  [<na>]
# 9615                         [<na>]                  [<na>]
# 9616                         [<na>]                  [<na>]
# 9617                         [<na>]                  [<na>]
# 9618                         [<na>]                  [<na>]
# 9619  [989, 769, 20500, 24200, 879]            [euro, baht]
# 9620                         [<na>]                  [<na>]

# %%
sdf = df[df["height"].apply(lambda x: x[0] if x[0]!="<nan>" else (x[1] if len(x)>1 else "<nan>")) != "<na>"]
sdf
# Out:
#                                                ID                      device  \
# 3        [http://www.wikidata.org/entity/Q161255]                1&1 SmartPad
# 229    [http://www.wikidata.org/entity/Q15261471]      Alcatel One Touch Fire
# 246    [http://www.wikidata.org/entity/Q24465055]              Alcatel Pop C1
# 303     [http://www.wikidata.org/entity/Q4748871]             Amstrad Mega PC
# 376    [http://www.wikidata.org/entity/Q16528397]          Archos 50 Platinum
# ...                                           ...                         ...
# 9606  [http://www.wikidata.org/entity/Q110397828]                   iPhone 14
# 9610     [http://www.wikidata.org/entity/Q300859]                  iPhone 3GS
# 9612   [http://www.wikidata.org/entity/Q20966885]              iPhone 6S Plus
# 9613   [http://www.wikidata.org/entity/Q26831164]                    iPhone 7
# 9614   [http://www.wikidata.org/entity/Q23309966]  iPhone SE (1st generation)
#
#                                                   color  \
# 3                                                [<na>]
# 229                                              [<na>]
# 246                                              [<na>]
# 303                                              [<na>]
# 376                                              [<na>]
# ...                                                 ...
# 9606  [blue, purple, Product Red, midnight blue, sta...
# 9610                                     [white, black]
# 9612                                             [<na>]
# 9613              [rose gold, gold, red, black, silver]
# 9614                    [rose gold, gold, grey, silver]
#
#                    inception precision  \
# 3                     [<na>]    [<na>]
# 229                   [<na>]    [<na>]
# 246                   [<na>]    [<na>]
# 303                   [<na>]    [<na>]
# 376                   [<na>]    [<na>]
# ...                      ...       ...
# 9606                  [<na>]    [<na>]
# 9610  [2009-06-08T00:00:00Z]     [day]
# 9612  [2015-09-09T00:00:00Z]     [day]
# 9613  [2016-09-07T00:00:00Z]     [day]
# 9614                  [<na>]    [<na>]
#
#                                      instance_ofLabel   height   height_unit  \
# 3                                   [tablet computer]  [196.6]  [millimetre]
# 229                                [smartphone model]    [115]  [millimetre]
# 246                                [smartphone model]  [112.5]  [millimetre]
# 303   [home video game console model, computer model]     [78]  [millimetre]
# 376                                [smartphone model]    [8.9]  [millimetre]
# ...                                               ...      ...           ...
# 9606                               [smartphone model]  [146.7]  [millimetre]
# 9610                               [smartphone model]  [115.5]  [millimetre]
# 9612                               [smartphone model]  [158.2]  [millimetre]
# 9613                                     [smartphone]  [138.3]  [millimetre]
# 9614                               [smartphone model]  [123.8]  [millimetre]
#
#        width    width_unit   weight weight_unit  \
# 3      [130]  [millimetre]    [470]      [gram]
# 229     [62]  [millimetre]    [108]      [gram]
# 246     [62]  [millimetre]    [100]      [gram]
# 303    [325]  [millimetre]   [<na>]      [<na>]
# 376   [72.4]  [millimetre]  [160.2]      [gram]
# ...      ...           ...      ...         ...
# 9606  [71.5]  [millimetre]    [172]      [gram]
# 9610  [62.1]  [millimetre]    [135]      [gram]
# 9612  [77.9]  [millimetre]    [192]      [gram]
# 9613  [67.1]  [millimetre]    [138]      [gram]
# 9614  [58.6]  [millimetre]    [113]      [gram]
#
#                               price              price_unit
# 3                            [<na>]                  [<na>]
# 229                          [<na>]                  [<na>]
# 246                          [<na>]                  [<na>]
# 303                          [<na>]                  [<na>]
# 376                          [<na>]                  [<na>]
# ...                             ...                     ...
# 9606                          [799]  [United States dollar]
# 9610                         [<na>]                  [<na>]
# 9612                         [<na>]                  [<na>]
# 9613  [989, 20500, 879, 769, 24200]            [euro, baht]
# 9614                         [<na>]                  [<na>]
#
# [317 rows x 14 columns]

# %% [markdown]
# # Import individual subclasses

# %%
from qwikidata.sparql import get_subclasses_of_item, return_sparql_query_results
subclasses = get_subclasses_of_item("Q68")

# %%
query = """
SELECT DISTINCT ?item ?itemLabel ?classLabel
WHERE {
  # ?item wdt:P31/wdt:P279* ?class .
  # ?class wdt:P279* ?ancestor .
  # ?ancestor p:P279 ?qualifierStatement .
  # ?qualifierStatement pq:P642 ?subClassOfQ68 .
  # ?subClassOfQ68 wdt:P279* wd:Q68 .
SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
}
"""
res = return_sparql_query_results(query)
df = pd.json_normalize(res["results"]["bindings"])
df = df[["item.value", "itemLabel.value", "classLabel.value"]]
df.columns = ["item", "itemLabel", "classLabel"]
df.head()
# Out:
#                                         item    itemLabel         classLabel
# 0    http://www.wikidata.org/entity/Q7517814       Simile     computer virus
# 1    http://www.wikidata.org/entity/Q8073103        Zmist     computer virus
# 2  http://www.wikidata.org/entity/Q110662443  FlorisBoard  computer keyboard
# 3    http://www.wikidata.org/entity/Q2124587        RST.b     computer virus
# 4    http://www.wikidata.org/entity/Q4669447      Abraxas     computer virus

# %%
df[df.itemLabel.str.contains("iPhone")]
# Out:
#                                            item                   itemLabel
# 1434     http://www.wikidata.org/entity/Q300859                  iPhone 3GS  \
# 1560     http://www.wikidata.org/entity/Q621427                      iPhone
# 2939     http://www.wikidata.org/entity/Q621427                      iPhone
# 2994     http://www.wikidata.org/entity/Q300859                  iPhone 3GS
# 3811   http://www.wikidata.org/entity/Q20966885              iPhone 6S Plus
# 4090   http://www.wikidata.org/entity/Q23309966  iPhone SE (1st generation)
# 4361   http://www.wikidata.org/entity/Q20966885              iPhone 6S Plus
# 4398   http://www.wikidata.org/entity/Q23309966  iPhone SE (1st generation)
# 4658   http://www.wikidata.org/entity/Q66816688      iPhone 5s, model A1533
# 5278  http://www.wikidata.org/entity/Q100332903                   iPhone 12
# 5281  http://www.wikidata.org/entity/Q108541719               iPhone 13 Pro
# 5310  http://www.wikidata.org/entity/Q108541666              iPhone 13 mini
# 5315  http://www.wikidata.org/entity/Q108118280                   iPhone 13
# 5325  http://www.wikidata.org/entity/Q108541741           iPhone 13 Pro Max
# 5706  http://www.wikidata.org/entity/Q110397828                   iPhone 14
# 5744  http://www.wikidata.org/entity/Q113800722               iPhone 14 Pro
# 5745  http://www.wikidata.org/entity/Q113816207              iPhone 14 Plus
# 5746  http://www.wikidata.org/entity/Q113816991           iPhone 14 Pro Max
# 6052  http://www.wikidata.org/entity/Q110397828                   iPhone 14
# 6079  http://www.wikidata.org/entity/Q113800722               iPhone 14 Pro
# 6080  http://www.wikidata.org/entity/Q113816207              iPhone 14 Plus
# 6081  http://www.wikidata.org/entity/Q113816991           iPhone 14 Pro Max
# 6189  http://www.wikidata.org/entity/Q100332903                   iPhone 12
# 6216   http://www.wikidata.org/entity/Q66816688      iPhone 5s, model A1533
# 9278  http://www.wikidata.org/entity/Q108541719               iPhone 13 Pro
# 9291  http://www.wikidata.org/entity/Q108541666              iPhone 13 mini
# 9294  http://www.wikidata.org/entity/Q108118280                   iPhone 13
# 9295  http://www.wikidata.org/entity/Q108541741           iPhone 13 Pro Max
#
#             classLabel
# 1434  smartphone model
# 1560  smartphone model
# 2939    computer model
# 2994    computer model
# 3811  smartphone model
# 4090  smartphone model
# 4361    computer model
# 4398    computer model
# 4658    computer model
# 5278    computer model
# 5281    computer model
# 5310    computer model
# 5315    computer model
# 5325    computer model
# 5706  smartphone model
# 5744  smartphone model
# 5745  smartphone model
# 5746  smartphone model
# 6052    computer model
# 6079    computer model
# 6080    computer model
# 6081    computer model
# 6189  smartphone model
# 6216  smartphone model
# 9278  smartphone model
# 9291  smartphone model
# 9294  smartphone model
# 9295  smartphone model
